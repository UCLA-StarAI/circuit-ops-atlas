# %%
using Revise
using LogicCircuits, ProbabilisticCircuits

include("product.jl");
include("log.jl");
include("support_circuit.jl");
include("real_power.jl");
include("integrate.jl");
includet("information.jl");
include("quotient.jl");

# %% [markdown]
# Pipeline

# %%
function ent(pc::ProbCircuit)
    println("> Size of the input circuits: pc - $(num_edges(pc))")
    t = @elapsed log_pc = log_circuit(pc; log_prob = true)
    println("> Computing log(pc) took $(t) seconds; the result circuit has $(num_edges(log_pc)) edges")
    t = @elapsed pc_t_log_pc = product_circuit(pc, log_pc; m_log_prob = true, n_log_prob = false, compatible = true)
    println("> Computing pc * log(pc) took $(t) seconds; the result circuit has $(num_edges(pc_t_log_pc)) edges")
    t = @elapsed ent_val = -integrate_circuit(pc_t_log_pc; log_prob = false)
    println("> Computing int(pc * log(pc)) took $(t) seconds.")
    println("> The entropy of pc is $(ent_val).")
end
# Out:
# ent (generic function with 1 method)

# %%
function xent(pc1::ProbCircuit, pc2::ProbCircuit)
    println("> Size of the input circuits: pc1 - $(num_edges(pc1)), pc2 - $(num_edges(pc2))")
    t = @elapsed log_pc2 = log_circuit(pc2; log_prob = true)
    println("> Computing log(pc2) took $(t) seconds; the result circuit has $(num_edges(log_pc2)) edges")
    t = @elapsed pc1_t_log_pc2 = product_circuit(pc1, log_pc2; m_log_prob = true, n_log_prob = false, 
                                                 compatible = true)
    println("> Computing pc1 * log(pc2) took $(t) seconds; the result circuit has $(num_edges(pc1_t_log_pc2)) edges")
    t = @elapsed xent_val = -integrate_circuit(pc1_t_log_pc2; log_prob = false)
    println("> Computing int(pc1 * log(pc2)) took $(t) seconds.")
    println("> The cross entropy between pc1 and pc2 is $(xent_val).")
    num_edges(pc1), num_edges(pc2), num_edges(log_pc2), num_edges(pc1_t_log_pc2)
end
# Out:
# xent (generic function with 1 method)

# %%
function kld(pc1::ProbCircuit, pc2::ProbCircuit)
    println("> Size of the input circuits: pc1 - $(num_edges(pc1)), pc2 - $(num_edges(pc2))")
    t = @elapsed inv_pc2 = circuit_real_power(pc2, -1.0)
    println("> Computing 1/pc2 took $(t) seconds; the result circuit has $(num_edges(inv_pc2)) edges")
    t = @elapsed pc1_q_pc2 = product_circuit(pc1, inv_pc2; m_log_prob = true, n_log_prob = true, compatible = true)
    println("> Computing pc1/pc2 took $(t) seconds; the result circuit has $(num_edges(pc1_q_pc2)) edges")
    t = @elapsed log_pc1_q_pc2 = log_circuit(pc1_q_pc2; log_prob = false)
    println("> Computing log(pc1/pc2) took $(t) seconds; the result circuit has $(num_edges(log_pc1_q_pc2)) edges")
    t = @elapsed pc1_t_log_pc1_q_pc2 = product_circuit(pc1, log_pc1_q_pc2; m_log_prob = true, n_log_prob = false, compatible = true)
    println("> Computing pc1 * log(pc1/pc2) took $(t) seconds; the result circuit has $(num_edges(pc1_t_log_pc1_q_pc2)) edges")
    t = @elapsed kld_val = integrate_circuit(pc1_t_log_pc1_q_pc2; log_prob = false)
    println("> Computing int(pc1 * log(pc1/pc2)) took $(t) seconds.")
    println("> The KLD between pc1 and pc2 is $(kld_val).")
    num_edges(pc1_q_pc2), num_edges(log_pc1_q_pc2), num_edges(pc1_t_log_pc1_q_pc2)
end
# Out:
# kld (generic function with 1 method)

# %%
function reiny_alpha_div(pc1::ProbCircuit, pc2::ProbCircuit; alpha::Float64)
    println("> Size of the input circuits: pc1 - $(num_edges(pc1)), pc2 - $(num_edges(pc2))")
    t = @elapsed powpc1 = circuit_real_power(pc1, alpha)
    println("> Computing pc1^alpha took $(t) seconds; the result circuit has $(num_edges(powpc1)) edges")
    t = @elapsed powpc2 = circuit_real_power(pc2, 1.0 - alpha)
    println("> Computing pc2^(1-alpha) took $(t) seconds; the result circuit has $(num_edges(powpc2)) edges")
    t = @elapsed powpc1_t_powpc2 = product_circuit(powpc1, powpc2; m_log_prob = true, n_log_prob = true, 
                                                   compatible = true)
    println("> Computing pc1^alpha * pc2^(1-alpha) took $(t) seconds; the result circuit has " *
            "$(num_edges(powpc1_t_powpc2)) edges")
    t = @elapsed reiny_val = log(integrate_circuit(powpc1_t_powpc2; log_prob = false)) / (1.0 - alpha)
    println("> Computing int(pc1^alpha * pc2^(1-alpha)) took $(t) seconds.")
    println("> The Reiny's Alpha Divergence between pc1 and pc2 is $(reiny_val).")
    num_edges(powpc1), num_edges(powpc2), num_edges(powpc1_t_powpc2)
end
# Out:
# reiny_alpha_div (generic function with 1 method)

# %%
function renyi_entropy(pc::ProbCircuit; alpha::Float64)
    println("> Size of the input circuit: pc - $(num_edges(pc))")
    t = @elapsed powpc = circuit_real_power(pc, alpha)
    println("> Computing pc^alpha took $(t) seconds; the result circuit has $(num_edges(powpc)) edges")
    t = @elapsed reiny_val = log(integrate_circuit(powpc; log_prob = true)) / (1.0 - alpha)
    println("> Computing int(pc^alpha) took $(t) seconds.")
    reiny_val
end
# Out:
# renyi_entropy (generic function with 1 method)

# %%
function cs_div(pc1::ProbCircuit, pc2::ProbCircuit)
    println("> Size of the input circuits: pc1 - $(num_edges(pc1)), pc2 - $(num_edges(pc2))")
    t = @elapsed pc1_m_pc2 = product_circuit(pc1, pc2; m_log_prob = true, n_log_prob = true, compatible = true)
    println("> Computing pc1*pc2 took $(t) seconds; the result circuit has $(num_edges(pc1_m_pc2)) edges")
    t = @elapsed pc1_sq = circuit_real_power(pc1, 2.0)
    println("> Computing pc1^2 took $(t) seconds; the result circuit has $(num_edges(pc1_sq)) edges")
    t = @elapsed pc2_sq = circuit_real_power(pc2, 2.0)
    println("> Computing pc2^2 took $(t) seconds; the result circuit has $(num_edges(pc2_sq)) edges")
    t = @elapsed div = -log(integrate_circuit(pc1_m_pc2; log_prob = false) / sqrt(
        integrate_circuit(pc1_sq; log_prob = true) * integrate_circuit(pc2_sq; log_prob = true)
    ))
    println("> Computing cs div took $(t) seconds.")
    div
end
# Out:
# cs_div (generic function with 1 method)

# %%
for dataset_name in twenty_dataset_names
    pc1 = load_prob_circuit("pcs/$(dataset_name)_200.psdd");
    pc2 = load_prob_circuit("pcs/$(dataset_name)_500.psdd");
    
    println("=========================================")
    println(dataset_name)
    println("")
    pc1_pc2 = product_circuit(pc1, pc2; m_log_prob = true, n_log_prob = true, compatible = true)
    println("> PC1 * PC2 $(num_edges(pc1_pc2)) edges")
    println("")
    ent(pc1)
    println("")
    pc1_size, pc2_size, log_pc2, p_r = xent(pc1, pc2)
    println("")
    pc1_q_pc2, log_s, p_t = kld(pc1, pc2)
    println("")
    pc1_a, pc2_a, pc1a_pc2a = reiny_alpha_div(pc1, pc2; alpha = 1.5)
    
    println("$(pc1_size) & $(pc2_size) & $(pc1_a) & $(pc2_a) & $(log_pc2) & $(pc1_q_pc2) & $(log_s) & " * 
            "$(num_edges(pc1_pc2)) & $(p_r) & $(p_t) & $(pc1a_pc2a)")
end
# Out:
# =========================================
# accidents
#
# > PC1 * PC2 8299 edges
#
# > Size of the input circuits: pc - 3193
# > Computing log(pc) took 1.758061784 seconds; the result circuit has 11564 edges
# > Computing pc * log(pc) took 0.145833363 seconds; the result circuit has 11564 edges
# > Computing int(pc * log(pc)) took 0.279742736 seconds.
# > The entropy of pc is 32.40056439544114.
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing log(pc2) took 0.252252482 seconds; the result circuit has 29891 edges
# > Computing pc1 * log(pc2) took 0.115413004 seconds; the result circuit has 30007 edges
# > Computing int(pc1 * log(pc2)) took 0.01103132 seconds.
# > The cross entropy between pc1 and pc2 is 34.05829064870709.
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing 1/pc2 took 0.68492835 seconds; the result circuit has 8183 edges
# > Computing pc1/pc2 took 0.030132439 seconds; the result circuit has 8299 edges
# > Computing log(pc1/pc2) took 0.022388278 seconds; the result circuit has 30239 edges
# > Computing pc1 * log(pc1/pc2) took 0.113479654 seconds; the result circuit has 30239 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.010801284 seconds.
# > The KLD between pc1 and pc2 is 1.6577262532659658.
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing pc1^alpha took 0.002607961 seconds; the result circuit has 3193 edges
# > Computing pc2^(1-alpha) took 0.006593732 seconds; the result circuit has 8183 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.029365055 seconds; the result circuit has 8299 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.002904644 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -6.555987547340751.
# 3193 & 8183 & 3193 & 8183 & 29891 & 8299 & 30239 & 8299 & 30007 & 30239 & 8299
# =========================================
# ad
#
# > PC1 * PC2 21920 edges
#
# > Size of the input circuits: pc - 17744
# > Computing log(pc) took 0.076670587 seconds; the result circuit has 62370 edges
# > Computing pc * log(pc) took 0.124411935 seconds; the result circuit has 62370 edges
# > Computing int(pc * log(pc)) took 0.022663653 seconds.
# > The entropy of pc is 19.197482207596337.
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing log(pc2) took 0.088937428 seconds; the result circuit has 76870 edges
# > Computing pc1 * log(pc2) took 0.111797278 seconds; the result circuit has 77114 edges
# > Computing int(pc1 * log(pc2)) took 0.063332645 seconds.
# > The cross entropy between pc1 and pc2 is 19.273256855320703.
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing 1/pc2 took 0.020796698 seconds; the result circuit has 21676 edges
# > Computing pc1/pc2 took 0.032808687 seconds; the result circuit has 21920 edges
# > Computing log(pc1/pc2) took 0.088011391 seconds; the result circuit has 77602 edges
# > Computing pc1 * log(pc1/pc2) took 0.111807984 seconds; the result circuit has 77602 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.028929972 seconds.
# > The KLD between pc1 and pc2 is 0.07577464772422951.
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing pc1^alpha took 0.021096509 seconds; the result circuit has 17744 edges
# > Computing pc2^(1-alpha) took 0.021351397 seconds; the result circuit has 21676 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.035132123 seconds; the result circuit has 21920 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.008847308 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.19909141036434766.
# 17744 & 21676 & 17744 & 21676 & 76870 & 21920 & 77602 & 21920 & 77114 & 77602 & 21920
# =========================================
# baudio
#
# > PC1 * PC2 45950 edges
#
# > Size of the input circuits: pc - 10278
# > Computing log(pc) took 0.054572214 seconds; the result circuit has 37585 edges
# > Computing pc * log(pc) took 0.304421667 seconds; the result circuit has 37585 edges
# > Computing int(pc * log(pc)) took 0.014253076 seconds.
# > The entropy of pc is 42.80516164785353.
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing log(pc2) took 0.265762952 seconds; the result circuit has 168062 edges
# > Computing pc1 * log(pc2) took 1.492523729 seconds; the result circuit has 168148 edges
# > Computing int(pc1 * log(pc2)) took 0.0702684 seconds.
# > The cross entropy between pc1 and pc2 is 43.52300808111336.
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing 1/pc2 took 0.219380629 seconds; the result circuit has 45864 edges
# > Computing pc1/pc2 took 0.462010978 seconds; the result circuit has 45950 edges
# > Computing log(pc1/pc2) took 0.161962141 seconds; the result circuit has 168320 edges
# > Computing pc1 * log(pc1/pc2) took 1.448214492 seconds; the result circuit has 168320 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.070360328 seconds.
# > The KLD between pc1 and pc2 is 0.717846433259805.
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing pc1^alpha took 0.008601573 seconds; the result circuit has 10278 edges
# > Computing pc2^(1-alpha) took 0.039203861 seconds; the result circuit has 45864 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.367351927 seconds; the result circuit has 45950 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.017512165 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -1.1474421894496463.
# 10278 & 45864 & 10278 & 45864 & 168062 & 45950 & 168320 & 45950 & 168148 & 168320 & 45950
# =========================================
# bbc
#
# > PC1 * PC2 17282 edges
#
# > Size of the input circuits: pc - 13884
# > Computing log(pc) took 0.094227307 seconds; the result circuit has 49321 edges
# > Computing pc * log(pc) took 0.078817449 seconds; the result circuit has 49321 edges
# > Computing int(pc * log(pc)) took 0.01775742 seconds.
# > The entropy of pc is 250.73399519523812.
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing log(pc2) took 0.046165819 seconds; the result circuit has 60857 edges
# > Computing pc1 * log(pc2) took 0.130917976 seconds; the result circuit has 61123 edges
# > Computing int(pc1 * log(pc2)) took 0.021109597 seconds.
# > The cross entropy between pc1 and pc2 is 251.10839774577622.
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing 1/pc2 took 0.015109266 seconds; the result circuit has 17016 edges
# > Computing pc1/pc2 took 0.026532589 seconds; the result circuit has 17282 edges
# > Computing log(pc1/pc2) took 0.049209897 seconds; the result circuit has 61655 edges
# > Computing pc1 * log(pc1/pc2) took 0.135855201 seconds; the result circuit has 61655 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.02193743 seconds.
# > The KLD between pc1 and pc2 is 0.3744025505383301.
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing pc1^alpha took 0.011691579 seconds; the result circuit has 13884 edges
# > Computing pc2^(1-alpha) took 0.014658769 seconds; the result circuit has 17016 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.027262673 seconds; the result circuit has 17282 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.006719211 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.5514099793516106.
# 13884 & 17016 & 13884 & 17016 & 60857 & 17282 & 61655 & 17282 & 61123 & 61655 & 17282
# =========================================
# bnetflix
#
# > PC1 * PC2 14706 edges
#
# > Size of the input circuits: pc - 5068
# > Computing log(pc) took 0.013215294 seconds; the result circuit has 18493 edges
# > Computing pc * log(pc) took 0.080947295 seconds; the result circuit has 18493 edges
# > Computing int(pc * log(pc)) took 0.005788789 seconds.
# > The entropy of pc is 59.21830440898668.
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing log(pc2) took 0.042142242 seconds; the result circuit has 53571 edges
# > Computing pc1 * log(pc2) took 0.15565885 seconds; the result circuit has 53641 edges
# > Computing int(pc1 * log(pc2)) took 0.052703995 seconds.
# > The cross entropy between pc1 and pc2 is 59.75211602725196.
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing 1/pc2 took 0.011857101 seconds; the result circuit has 14636 edges
# > Computing pc1/pc2 took 0.041696912 seconds; the result circuit has 14706 edges
# > Computing log(pc1/pc2) took 0.040353239 seconds; the result circuit has 53781 edges
# > Computing pc1 * log(pc1/pc2) took 0.195705083 seconds; the result circuit has 53781 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.01886577 seconds.
# > The KLD between pc1 and pc2 is 0.5338116182652547.
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing pc1^alpha took 0.004171971 seconds; the result circuit has 5068 edges
# > Computing pc2^(1-alpha) took 0.011065207 seconds; the result circuit has 14636 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.040944262 seconds; the result circuit has 14706 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005255768 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.8237090208137337.
# 5068 & 14636 & 5068 & 14636 & 53571 & 14706 & 53781 & 14706 & 53641 & 53781 & 14706
# =========================================
# book
#
# > PC1 * PC2 12943 edges
#
# > Size of the input circuits: pc - 7718
# > Computing log(pc) took 0.019442373 seconds; the result circuit has 27584 edges
# > Computing pc * log(pc) took 0.07438307 seconds; the result circuit has 27584 edges
# > Computing int(pc * log(pc)) took 0.0092449 seconds.
# > The entropy of pc is 36.706711083535474.
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing log(pc2) took 0.032943888 seconds; the result circuit has 45985 edges
# > Computing pc1 * log(pc2) took 0.081563931 seconds; the result circuit has 46197 edges
# > Computing int(pc1 * log(pc2)) took 0.016921314 seconds.
# > The cross entropy between pc1 and pc2 is 37.001537898136576.
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing 1/pc2 took 0.009873365 seconds; the result circuit has 12731 edges
# > Computing pc1/pc2 took 0.021762027 seconds; the result circuit has 12943 edges
# > Computing log(pc1/pc2) took 0.033588171 seconds; the result circuit has 46621 edges
# > Computing pc1 * log(pc1/pc2) took 0.082461209 seconds; the result circuit has 46621 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016673879 seconds.
# > The KLD between pc1 and pc2 is 0.2948268146010812.
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing pc1^alpha took 0.006238958 seconds; the result circuit has 7718 edges
# > Computing pc2^(1-alpha) took 0.009986557 seconds; the result circuit has 12731 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.022399575 seconds; the result circuit has 12943 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004636922 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.42067644194405474.
# 7718 & 12731 & 7718 & 12731 & 45985 & 12943 & 46621 & 12943 & 46197 & 46621 & 12943
# =========================================
# c20ng
#
# > PC1 * PC2 14886 edges
#
# > Size of the input circuits: pc - 11386
# > Computing log(pc) took 0.029023927 seconds; the result circuit has 40188 edges
# > Computing pc * log(pc) took 0.056750805 seconds; the result circuit has 40188 edges
# > Computing int(pc * log(pc)) took 0.0137123 seconds.
# > The entropy of pc is 147.7955662472699.
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing log(pc2) took 0.036683986 seconds; the result circuit has 52120 edges
# > Computing pc1 * log(pc2) took 0.11857668 seconds; the result circuit has 52376 edges
# > Computing int(pc1 * log(pc2)) took 0.017869837 seconds.
# > The cross entropy between pc1 and pc2 is 148.0782504585418.
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing 1/pc2 took 0.012009273 seconds; the result circuit has 14630 edges
# > Computing pc1/pc2 took 0.02278731 seconds; the result circuit has 14886 edges
# > Computing log(pc1/pc2) took 0.039122752 seconds; the result circuit has 52888 edges
# > Computing pc1 * log(pc1/pc2) took 0.08428105 seconds; the result circuit has 52888 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.018887962 seconds.
# > The KLD between pc1 and pc2 is 0.28268421127200144.
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing pc1^alpha took 0.009901158 seconds; the result circuit has 11386 edges
# > Computing pc2^(1-alpha) took 0.011868671 seconds; the result circuit has 14630 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.023768191 seconds; the result circuit has 14886 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005253628 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.4650706460435336.
# 11386 & 14630 & 11386 & 14630 & 52120 & 14886 & 52888 & 14886 & 52376 & 52888 & 14886
# =========================================
# cr52
#
# > PC1 * PC2 14546 edges
#
# > Size of the input circuits: pc - 10912
# > Computing log(pc) took 0.027276346 seconds; the result circuit has 38466 edges
# > Computing pc * log(pc) took 0.057236147 seconds; the result circuit has 38466 edges
# > Computing int(pc * log(pc)) took 0.012431595 seconds.
# > The entropy of pc is 103.67129218526738.
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing log(pc2) took 0.038532052 seconds; the result circuit has 51094 edges
# > Computing pc1 * log(pc2) took 0.088674825 seconds; the result circuit has 51292 edges
# > Computing int(pc1 * log(pc2)) took 0.018246099 seconds.
# > The cross entropy between pc1 and pc2 is 103.86047923886721.
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing 1/pc2 took 0.011352408 seconds; the result circuit has 14348 edges
# > Computing pc1/pc2 took 0.023592745 seconds; the result circuit has 14546 edges
# > Computing log(pc1/pc2) took 0.06931808 seconds; the result circuit has 51688 edges
# > Computing pc1 * log(pc1/pc2) took 0.087700625 seconds; the result circuit has 51688 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.018339519 seconds.
# > The KLD between pc1 and pc2 is 0.18918705359984717.
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing pc1^alpha took 0.009112455 seconds; the result circuit has 10912 edges
# > Computing pc2^(1-alpha) took 0.011634347 seconds; the result circuit has 14348 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.024304738 seconds; the result circuit has 14546 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005479374 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.3244837684761142.
# 10912 & 14348 & 10912 & 14348 & 51094 & 14546 & 51688 & 14546 & 51292 & 51688 & 14546
# =========================================
# cwebkb
#
# > PC1 * PC2 13653 edges
#
# > Size of the input circuits: pc - 10598
# > Computing log(pc) took 0.026718204 seconds; the result circuit has 37564 edges
# > Computing pc * log(pc) took 0.0545805 seconds; the result circuit has 37564 edges
# > Computing int(pc * log(pc)) took 0.012966234 seconds.
# > The entropy of pc is 155.91078086898125.
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing log(pc2) took 0.033534895 seconds; the result circuit has 47859 edges
# > Computing pc1 * log(pc2) took 0.068903008 seconds; the result circuit has 48115 edges
# > Computing int(pc1 * log(pc2)) took 0.051422772 seconds.
# > The cross entropy between pc1 and pc2 is 156.25023067909387.
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing 1/pc2 took 0.010645869 seconds; the result circuit has 13397 edges
# > Computing pc1/pc2 took 0.021460936 seconds; the result circuit has 13653 edges
# > Computing log(pc1/pc2) took 0.036124721 seconds; the result circuit has 48627 edges
# > Computing pc1 * log(pc1/pc2) took 0.072558131 seconds; the result circuit has 48627 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016990715 seconds.
# > The KLD between pc1 and pc2 is 0.33944981011289377.
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing pc1^alpha took 0.008505148 seconds; the result circuit has 10598 edges
# > Computing pc2^(1-alpha) took 0.011288373 seconds; the result circuit has 13397 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.048884066 seconds; the result circuit has 13653 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005029054 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.48145521926605633.
# 10598 & 13397 & 10598 & 13397 & 47859 & 13653 & 48627 & 13653 & 48115 & 48627 & 13653
# =========================================
# dna
#
# > PC1 * PC2 857029 edges
#
# > Size of the input circuits: pc - 73828
# > Computing log(pc) took 0.221542863 seconds; the result circuit has 270535 edges
# > Computing pc * log(pc) took 3.552670617 seconds; the result circuit has 270535 edges
# > Computing int(pc * log(pc)) took 0.115405112 seconds.
# > The entropy of pc is 86.75201818365386.
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing log(pc2) took 2.814790303 seconds; the result circuit has 3141981 edges
# > Computing pc1 * log(pc2) took 43.636572344 seconds; the result circuit has 3142055 edges
# > Computing int(pc1 * log(pc2)) took 1.591675466 seconds.
# > The cross entropy between pc1 and pc2 is 93.30240984842088.
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing 1/pc2 took 0.870741593 seconds; the result circuit has 856955 edges
# > Computing pc1/pc2 took 10.522954407 seconds; the result circuit has 857029 edges
# > Computing log(pc1/pc2) took 2.921172945 seconds; the result circuit has 3142203 edges
# > Computing pc1 * log(pc1/pc2) took 42.866988941 seconds; the result circuit has 3142203 edges
# > Computing int(pc1 * log(pc1/pc2)) took 1.566064493 seconds.
# > The KLD between pc1 and pc2 is 6.550391664767006.
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing pc1^alpha took 0.062693596 seconds; the result circuit has 73828 edges
# > Computing pc2^(1-alpha) took 0.876999526 seconds; the result circuit has 856955 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 10.95474192 seconds; the result circuit has 857029 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.421149402 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -13.621780838550412.
# 73828 & 856955 & 73828 & 856955 & 3141981 & 857029 & 3142203 & 857029 & 3142055 & 3142203 & 857029
# =========================================
# jester
#
# > PC1 * PC2 35479 edges
#
# > Size of the input circuits: pc - 6475
# > Computing log(pc) took 0.018704308 seconds; the result circuit has 23636 edges
# > Computing pc * log(pc) took 0.100831568 seconds; the result circuit has 23636 edges
# > Computing int(pc * log(pc)) took 0.008053496 seconds.
# > The entropy of pc is 56.448165569922416.
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing log(pc2) took 0.103423719 seconds; the result circuit has 129579 edges
# > Computing pc1 * log(pc2) took 0.533407463 seconds; the result circuit has 129689 edges
# > Computing int(pc1 * log(pc2)) took 0.051425928 seconds.
# > The cross entropy between pc1 and pc2 is 57.51142426885051.
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing 1/pc2 took 0.029921218 seconds; the result circuit has 35369 edges
# > Computing pc1/pc2 took 0.134780681 seconds; the result circuit has 35479 edges
# > Computing log(pc1/pc2) took 0.107784894 seconds; the result circuit has 129909 edges
# > Computing pc1 * log(pc1/pc2) took 0.537117733 seconds; the result circuit has 129909 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.054062567 seconds.
# > The KLD between pc1 and pc2 is 1.0632586989280854.
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing pc1^alpha took 0.005719108 seconds; the result circuit has 6475 edges
# > Computing pc2^(1-alpha) took 0.030881195 seconds; the result circuit has 35369 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.13897745 seconds; the result circuit has 35479 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.014264253 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -1.6853136774624742.
# 6475 & 35369 & 6475 & 35369 & 129579 & 35479 & 129909 & 35479 & 129689 & 129909 & 35479
# =========================================
# kdd
#
# > PC1 * PC2 50417 edges
#
# > Size of the input circuits: pc - 4963
# > Computing log(pc) took 0.013699697 seconds; the result circuit has 18127 edges
# > Computing pc * log(pc) took 0.125810019 seconds; the result circuit has 18127 edges
# > Computing int(pc * log(pc)) took 0.006077358 seconds.
# > The entropy of pc is 2.4499956450929483.
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing log(pc2) took 0.226162581 seconds; the result circuit has 184575 edges
# > Computing pc1 * log(pc2) took 2.076376197 seconds; the result circuit has 184615 edges
# > Computing int(pc1 * log(pc2)) took 0.149092682 seconds.
# > The cross entropy between pc1 and pc2 is 2.4822370246489984.
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing 1/pc2 took 0.040957359 seconds; the result circuit has 50377 edges
# > Computing pc1/pc2 took 0.527252103 seconds; the result circuit has 50417 edges
# > Computing log(pc1/pc2) took 0.152522234 seconds; the result circuit has 184695 edges
# > Computing pc1 * log(pc1/pc2) took 1.780406418 seconds; the result circuit has 184695 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.074884215 seconds.
# > The KLD between pc1 and pc2 is 0.03224137955604949.
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing pc1^alpha took 0.00435989 seconds; the result circuit has 4963 edges
# > Computing pc2^(1-alpha) took 0.044211462 seconds; the result circuit has 50377 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.446956479 seconds; the result circuit has 50417 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.021728402 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.07304605092566026.
# 4963 & 50377 & 4963 & 50377 & 184575 & 50417 & 184695 & 50417 & 184615 & 184695 & 50417
# =========================================
# kosarek
#
# > PC1 * PC2 13106 edges
#
# > Size of the input circuits: pc - 5115
# > Computing log(pc) took 0.014827244 seconds; the result circuit has 18477 edges
# > Computing pc * log(pc) took 0.161887479 seconds; the result circuit has 18477 edges
# > Computing int(pc * log(pc)) took 0.006094971 seconds.
# > The entropy of pc is 11.485021503770145.
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing log(pc2) took 0.063034081 seconds; the result circuit has 47354 edges
# > Computing pc1 * log(pc2) took 0.298739524 seconds; the result circuit has 47472 edges
# > Computing int(pc1 * log(pc2)) took 0.016907899 seconds.
# > The cross entropy between pc1 and pc2 is 11.684428276120638.
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing 1/pc2 took 0.010502913 seconds; the result circuit has 12988 edges
# > Computing pc1/pc2 took 0.077460817 seconds; the result circuit has 13106 edges
# > Computing log(pc1/pc2) took 0.037167783 seconds; the result circuit has 47708 edges
# > Computing pc1 * log(pc1/pc2) took 0.29838662 seconds; the result circuit has 47708 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016879014 seconds.
# > The KLD between pc1 and pc2 is 0.19940677235049156.
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing pc1^alpha took 0.004518289 seconds; the result circuit has 5115 edges
# > Computing pc2^(1-alpha) took 0.010472548 seconds; the result circuit has 12988 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.077353637 seconds; the result circuit has 13106 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004853795 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.3414242734454531.
# 5115 & 12988 & 5115 & 12988 & 47354 & 13106 & 47708 & 13106 & 47472 & 47708 & 13106
# =========================================
# msnbc
#
# > PC1 * PC2 6634 edges
#
# > Size of the input circuits: pc - 2765
# > Computing log(pc) took 0.034039832 seconds; the result circuit has 10089 edges
# > Computing pc * log(pc) took 0.095945443 seconds; the result circuit has 10089 edges
# > Computing int(pc * log(pc)) took 0.003318592 seconds.
# > The entropy of pc is 6.282982749895639.
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing log(pc2) took 0.045813466 seconds; the result circuit has 24111 edges
# > Computing pc1 * log(pc2) took 0.254197937 seconds; the result circuit has 24131 edges
# > Computing int(pc1 * log(pc2)) took 0.008713826 seconds.
# > The cross entropy between pc1 and pc2 is 6.394007219999606.
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing 1/pc2 took 0.005455087 seconds; the result circuit has 6614 edges
# > Computing pc1/pc2 took 0.066381741 seconds; the result circuit has 6634 edges
# > Computing log(pc1/pc2) took 0.019375752 seconds; the result circuit has 24171 edges
# > Computing pc1 * log(pc1/pc2) took 0.25436212 seconds; the result circuit has 24171 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.008769778 seconds.
# > The KLD between pc1 and pc2 is 0.1110244701039657.
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing pc1^alpha took 0.002261465 seconds; the result circuit has 2765 edges
# > Computing pc2^(1-alpha) took 0.005528284 seconds; the result circuit has 6614 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.066516409 seconds; the result circuit has 6634 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.002348598 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.18313379427044257.
# 2765 & 6614 & 2765 & 6614 & 24111 & 6634 & 24171 & 6634 & 24131 & 24171 & 6634
# =========================================
# msweb
#
# > PC1 * PC2 9175 edges
#
# > Size of the input circuits: pc - 4859
# > Computing log(pc) took 0.040767552 seconds; the result circuit has 17381 edges
# > Computing pc * log(pc) took 0.104780781 seconds; the result circuit has 17381 edges
# > Computing int(pc * log(pc)) took 0.005380013 seconds.
# > The entropy of pc is 10.155486310119123.
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing log(pc2) took 0.052546843 seconds; the result circuit has 32675 edges
# > Computing pc1 * log(pc2) took 0.150819793 seconds; the result circuit has 32825 edges
# > Computing int(pc1 * log(pc2)) took 0.01111124 seconds.
# > The cross entropy between pc1 and pc2 is 10.162931667964264.
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing 1/pc2 took 0.007689092 seconds; the result circuit has 9025 edges
# > Computing pc1/pc2 took 0.04009734 seconds; the result circuit has 9175 edges
# > Computing log(pc1/pc2) took 0.025462611 seconds; the result circuit has 33125 edges
# > Computing pc1 * log(pc1/pc2) took 0.150849288 seconds; the result circuit has 33125 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.011246683 seconds.
# > The KLD between pc1 and pc2 is 0.007445357845147155.
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing pc1^alpha took 0.004359887 seconds; the result circuit has 4859 edges
# > Computing pc2^(1-alpha) took 0.007667335 seconds; the result circuit has 9025 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.040077462 seconds; the result circuit has 9175 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.002989501 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.01038327650773606.
# 4859 & 9025 & 4859 & 9025 & 32675 & 9175 & 33125 & 9175 & 32825 & 33125 & 9175
# =========================================
# nltcs
#
# > PC1 * PC2 7202 edges
#
# > Size of the input circuits: pc - 2779
# > Computing log(pc) took 0.034648543 seconds; the result circuit has 10129 edges
# > Computing pc * log(pc) took 0.131516242 seconds; the result circuit has 10129 edges
# > Computing int(pc * log(pc)) took 0.003471628 seconds.
# > The entropy of pc is 6.125420227013054.
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing log(pc2) took 0.048156841 seconds; the result circuit has 26155 edges
# > Computing pc1 * log(pc2) took 0.377449724 seconds; the result circuit has 26183 edges
# > Computing int(pc1 * log(pc2)) took 0.009964872 seconds.
# > The cross entropy between pc1 and pc2 is 6.2351072248353585.
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing 1/pc2 took 0.006120518 seconds; the result circuit has 7174 edges
# > Computing pc1/pc2 took 0.095766811 seconds; the result circuit has 7202 edges
# > Computing log(pc1/pc2) took 0.021670343 seconds; the result circuit has 26239 edges
# > Computing pc1 * log(pc1/pc2) took 0.371778301 seconds; the result circuit has 26239 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.009802303 seconds.
# > The KLD between pc1 and pc2 is 0.10968699782230651.
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing pc1^alpha took 0.002436136 seconds; the result circuit has 2779 edges
# > Computing pc2^(1-alpha) took 0.006147161 seconds; the result circuit has 7174 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.096251514 seconds; the result circuit has 7202 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.002788585 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.2136957947761329.
# 2779 & 7174 & 2779 & 7174 & 26155 & 7202 & 26239 & 7202 & 26183 & 26239 & 7202
# =========================================
# plants
#
# > PC1 * PC2 64070 edges
#
# > Size of the input circuits: pc - 12909
# > Computing log(pc) took 0.03630345 seconds; the result circuit has 47275 edges
# > Computing pc * log(pc) took 0.551637396 seconds; the result circuit has 47275 edges
# > Computing int(pc * log(pc)) took 0.016946393 seconds.
# > The entropy of pc is 15.033179152400017.
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing log(pc2) took 0.293080511 seconds; the result circuit has 234661 edges
# > Computing pc1 * log(pc2) took 3.552869624 seconds; the result circuit has 234713 edges
# > Computing int(pc1 * log(pc2)) took 0.092379214 seconds.
# > The cross entropy between pc1 and pc2 is 16.311007100712775.
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing 1/pc2 took 0.050813031 seconds; the result circuit has 64018 edges
# > Computing pc1/pc2 took 0.665712424 seconds; the result circuit has 64070 edges
# > Computing log(pc1/pc2) took 0.195659901 seconds; the result circuit has 234817 edges
# > Computing pc1 * log(pc1/pc2) took 2.71476487 seconds; the result circuit has 234817 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.094256915 seconds.
# > The KLD between pc1 and pc2 is 1.2778279483127581.
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing pc1^alpha took 0.010779896 seconds; the result circuit has 12909 edges
# > Computing pc2^(1-alpha) took 0.054664592 seconds; the result circuit has 64018 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.662964377 seconds; the result circuit has 64070 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.026076024 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -3.8712657353901805.
# 12909 & 64018 & 12909 & 64018 & 234661 & 64070 & 234817 & 64070 & 234713 & 234817 & 64070
# =========================================
# pumsb_star
#
# > PC1 * PC2 12595 edges
#
# > Size of the input circuits: pc - 4277
# > Computing log(pc) took 0.011788109 seconds; the result circuit has 15459 edges
# > Computing pc * log(pc) took 0.070165099 seconds; the result circuit has 15459 edges
# > Computing int(pc * log(pc)) took 0.004756182 seconds.
# > The entropy of pc is 30.448249698414923.
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing log(pc2) took 0.035403708 seconds; the result circuit has 45500 edges
# > Computing pc1 * log(pc2) took 0.230160875 seconds; the result circuit has 45634 edges
# > Computing int(pc1 * log(pc2)) took 0.016046071 seconds.
# > The cross entropy between pc1 and pc2 is 34.242918908879886.
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing 1/pc2 took 0.010443126 seconds; the result circuit has 12461 edges
# > Computing pc1/pc2 took 0.064787541 seconds; the result circuit has 12595 edges
# > Computing log(pc1/pc2) took 0.03593284 seconds; the result circuit has 45902 edges
# > Computing pc1 * log(pc1/pc2) took 0.230257397 seconds; the result circuit has 45902 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016329901 seconds.
# > The KLD between pc1 and pc2 is 3.794669210464959.
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing pc1^alpha took 0.003607858 seconds; the result circuit has 4277 edges
# > Computing pc2^(1-alpha) took 0.010333371 seconds; the result circuit has 12461 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.064684074 seconds; the result circuit has 12595 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004454645 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -19.39999031349208.
# 4277 & 12461 & 4277 & 12461 & 45500 & 12595 & 45902 & 12595 & 45634 & 45902 & 12595
# =========================================
# tmovie
#
# > PC1 * PC2 11926 edges
#
# > Size of the input circuits: pc - 8309
# > Computing log(pc) took 0.022593651 seconds; the result circuit has 29803 edges
# > Computing pc * log(pc) took 0.205585333 seconds; the result circuit has 29803 edges
# > Computing int(pc * log(pc)) took 0.009916946 seconds.
# > The entropy of pc is 65.39573682801425.
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing log(pc2) took 0.032014996 seconds; the result circuit has 42374 edges
# > Computing pc1 * log(pc2) took 0.257669956 seconds; the result circuit has 42568 edges
# > Computing int(pc1 * log(pc2)) took 0.01479825 seconds.
# > The cross entropy between pc1 and pc2 is 65.54253059963418.
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing 1/pc2 took 0.009692844 seconds; the result circuit has 11732 edges
# > Computing pc1/pc2 took 0.065577932 seconds; the result circuit has 11926 edges
# > Computing log(pc1/pc2) took 0.033030047 seconds; the result circuit has 42956 edges
# > Computing pc1 * log(pc1/pc2) took 0.257631701 seconds; the result circuit has 42956 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.015013036 seconds.
# > The KLD between pc1 and pc2 is 0.1467937716198886.
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing pc1^alpha took 0.007057336 seconds; the result circuit has 8309 edges
# > Computing pc2^(1-alpha) took 0.009801265 seconds; the result circuit has 11732 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.06583342 seconds; the result circuit has 11926 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004057441 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.25634862557081556.
# 8309 & 11732 & 8309 & 11732 & 42374 & 11926 & 42956 & 11926 & 42568 & 42956 & 11926
# =========================================
# tretail
#
# > PC1 * PC2 14994 edges
#
# > Size of the input circuits: pc - 4790
# > Computing log(pc) took 0.013743269 seconds; the result circuit has 17383 edges
# > Computing pc * log(pc) took 0.075945305 seconds; the result circuit has 17383 edges
# > Computing int(pc * log(pc)) took 0.005375935 seconds.
# > The entropy of pc is 10.813896439395194.
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing log(pc2) took 0.070101613 seconds; the result circuit has 54554 edges
# > Computing pc1 * log(pc2) took 0.277664742 seconds; the result circuit has 54622 edges
# > Computing int(pc1 * log(pc2)) took 0.019737308 seconds.
# > The cross entropy between pc1 and pc2 is 10.855694725567409.
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing 1/pc2 took 0.012475882 seconds; the result circuit has 14926 edges
# > Computing pc1/pc2 took 0.070744097 seconds; the result circuit has 14994 edges
# > Computing log(pc1/pc2) took 0.042856075 seconds; the result circuit has 54758 edges
# > Computing pc1 * log(pc1/pc2) took 0.273365292 seconds; the result circuit has 54758 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.019789055 seconds.
# > The KLD between pc1 and pc2 is 0.04179828617221294.
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing pc1^alpha took 0.004213043 seconds; the result circuit has 4790 edges
# > Computing pc2^(1-alpha) took 0.012290414 seconds; the result circuit has 14926 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.070364891 seconds; the result circuit has 14994 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005541984 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.06841491024348624.
# 4790 & 14926 & 4790 & 14926 & 54554 & 14994 & 54758 & 14994 & 54622 & 54758 & 14994
# SystemError: opening file "pcs/binarized_mnist_200.psdd": No such file or directory
#
# Stacktrace:
#   [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#     @ Base ./error.jl:168
#   [2] #systemerror#62
#     @ ./error.jl:167 [inlined]
#   [3] systemerror
#     @ ./error.jl:167 [inlined]
#   [4] open(fname::String; lock::Bool, read::Nothing, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing)
#     @ Base ./iostream.jl:293
#   [5] open
#     @ ./iostream.jl:282 [inlined]
#   [6] open(f::typeof(LogicCircuits.LoadSave.parse_psdd_file), args::String; kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:328
#   [7] open
#     @ ./io.jl:328 [inlined]
#   [8] parse_psdd_file
#     @ ~/.julia/packages/LogicCircuits/neONa/src/LoadSave/circuit_loaders.jl:230 [inlined]
#   [9] load_prob_circuit
#     @ ~/.julia/packages/ProbabilisticCircuits/ARqaS/src/LoadSave/circuit_loaders.jl:40 [inlined]
#  [10] top-level scope
#     @ ./In[6]:2
#  [11] eval
#     @ ./boot.jl:360 [inlined]
#  [12] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %%
using Printf: @printf

# %%
for dataset_name in twenty_dataset_names[1:end-1]
    pc1 = ProbabilisticCircuits.load_prob_circuit("pcs/$(dataset_name)_200.psdd");
    pc2 = ProbabilisticCircuits.load_prob_circuit("pcs/$(dataset_name)_500.psdd");
    
    println("=========================================")
    println(dataset_name)
    println("")
    t1 = @elapsed ent(pc1);
    println("")
    t2 = @elapsed xent(pc1, pc2);
    println("")
    t3 = @elapsed kld(pc1, pc2);
    println("")
    
    t4 = @elapsed entropy(pc1);
    t5 = @elapsed myxent(pc1, pc2);
    t6 = @elapsed mykld(pc1, pc2)
    
    @printf("%.3f & %.3f & %.3f & %.3f & %.3f & %.3f\n", t1, t4, t2, t5, t3, t6)
    # println("$(t1) & $(t4) & $(t2) & $(t5) & $(t3) & $(t6)")
end
# Out:
# =========================================
# accidents
#
# > Size of the input circuits: pc - 3193
# > Computing log(pc) took 0.007937096 seconds; the result circuit has 11564 edges
# > Computing pc * log(pc) took 0.048401756 seconds; the result circuit has 11564 edges
# > Computing int(pc * log(pc)) took 0.003376639 seconds.
# > The entropy of pc is 32.40056439544114.
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing log(pc2) took 0.02115136 seconds; the result circuit has 29891 edges
# > Computing pc1 * log(pc2) took 0.12994314 seconds; the result circuit has 30007 edges
# > Computing int(pc1 * log(pc2)) took 0.010002092 seconds.
# > The cross entropy between pc1 and pc2 is 34.05829064870709.
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing 1/pc2 took 0.006517435 seconds; the result circuit has 8183 edges
# > Computing pc1/pc2 took 0.029060427 seconds; the result circuit has 8299 edges
# > Computing log(pc1/pc2) took 0.02282265 seconds; the result circuit has 30239 edges
# > Computing pc1 * log(pc1/pc2) took 0.128937009 seconds; the result circuit has 30239 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.010062699 seconds.
# > The KLD between pc1 and pc2 is 1.6577262532659658.
#
# 0.063& 0.001 & 0.182 & 0.038 & 0.223 & 0.049
# =========================================
# ad
#
# > Size of the input circuits: pc - 17744
# > Computing log(pc) took 0.065856137 seconds; the result circuit has 62370 edges
# > Computing pc * log(pc) took 0.091227719 seconds; the result circuit has 62370 edges
# > Computing int(pc * log(pc)) took 0.041412948 seconds.
# > The entropy of pc is 19.197482207596337.
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing log(pc2) took 0.060164103 seconds; the result circuit has 76870 edges
# > Computing pc1 * log(pc2) took 0.142098044 seconds; the result circuit has 77114 edges
# > Computing int(pc1 * log(pc2)) took 0.026647591 seconds.
# > The cross entropy between pc1 and pc2 is 19.273256855320703.
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing 1/pc2 took 0.020138473 seconds; the result circuit has 21676 edges
# > Computing pc1/pc2 took 0.048447321 seconds; the result circuit has 21920 edges
# > Computing log(pc1/pc2) took 0.062313129 seconds; the result circuit has 77602 edges
# > Computing pc1 * log(pc1/pc2) took 0.142488768 seconds; the result circuit has 77602 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.027643317 seconds.
# > The KLD between pc1 and pc2 is 0.07577464772422951.
#
# 0.223& 0.006 & 0.295 & 0.042 & 0.375 & 0.054
# =========================================
# baudio
#
# > Size of the input circuits: pc - 10278
# > Computing log(pc) took 0.027113653 seconds; the result circuit has 37585 edges
# > Computing pc * log(pc) took 0.310606404 seconds; the result circuit has 37585 edges
# > Computing int(pc * log(pc)) took 0.012686867 seconds.
# > The entropy of pc is 42.80516164785353.
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing log(pc2) took 0.155581451 seconds; the result circuit has 168062 edges
# > Computing pc1 * log(pc2) took 1.456473392 seconds; the result circuit has 168148 edges
# > Computing int(pc1 * log(pc2)) took 0.06935602 seconds.
# > The cross entropy between pc1 and pc2 is 43.52300808111336.
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing 1/pc2 took 0.102591792 seconds; the result circuit has 45864 edges
# > Computing pc1/pc2 took 0.375611602 seconds; the result circuit has 45950 edges
# > Computing log(pc1/pc2) took 0.139463191 seconds; the result circuit has 168320 edges
# > Computing pc1 * log(pc1/pc2) took 1.706678607 seconds; the result circuit has 168320 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.065344603 seconds.
# > The KLD between pc1 and pc2 is 0.717846433259805.
#
# 0.364& 0.004 & 1.827 & 1.660 & 2.552 & 1.572
# =========================================
# bbc
#
# > Size of the input circuits: pc - 13884
# > Computing log(pc) took 0.038727693 seconds; the result circuit has 49321 edges
# > Computing pc * log(pc) took 0.081754468 seconds; the result circuit has 49321 edges
# > Computing int(pc * log(pc)) took 0.017503991 seconds.
# > The entropy of pc is 250.73399519523812.
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing log(pc2) took 0.047673387 seconds; the result circuit has 60857 edges
# > Computing pc1 * log(pc2) took 0.097313437 seconds; the result circuit has 61123 edges
# > Computing int(pc1 * log(pc2)) took 0.05968125 seconds.
# > The cross entropy between pc1 and pc2 is 251.10839774577622.
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing 1/pc2 took 0.015219549 seconds; the result circuit has 17016 edges
# > Computing pc1/pc2 took 0.027693084 seconds; the result circuit has 17282 edges
# > Computing log(pc1/pc2) took 0.052382356 seconds; the result circuit has 61655 edges
# > Computing pc1 * log(pc1/pc2) took 0.097694221 seconds; the result circuit has 61655 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.023280608 seconds.
# > The KLD between pc1 and pc2 is 0.3744025505383301.
#
# 0.157& 0.004 & 0.255 & 0.038 & 0.276 & 0.062
# =========================================
# bnetflix
#
# > Size of the input circuits: pc - 5068
# > Computing log(pc) took 0.015268147 seconds; the result circuit has 18493 edges
# > Computing pc * log(pc) took 0.060167675 seconds; the result circuit has 18493 edges
# > Computing int(pc * log(pc)) took 0.006436588 seconds.
# > The entropy of pc is 59.21830440898668.
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing log(pc2) took 0.038879697 seconds; the result circuit has 53571 edges
# > Computing pc1 * log(pc2) took 0.15968816 seconds; the result circuit has 53641 edges
# > Computing int(pc1 * log(pc2)) took 0.053091527 seconds.
# > The cross entropy between pc1 and pc2 is 59.75211602725196.
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing 1/pc2 took 0.01300051 seconds; the result circuit has 14636 edges
# > Computing pc1/pc2 took 0.04238159 seconds; the result circuit has 14706 edges
# > Computing log(pc1/pc2) took 0.041649187 seconds; the result circuit has 53781 edges
# > Computing pc1 * log(pc1/pc2) took 0.159668954 seconds; the result circuit has 53781 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.019787691 seconds.
# > The KLD between pc1 and pc2 is 0.5338116182652547.
#
# 0.089& 0.002 & 0.291 & 0.177 & 0.324 & 0.146
# =========================================
# book
#
# > Size of the input circuits: pc - 7718
# > Computing log(pc) took 0.021912908 seconds; the result circuit has 27584 edges
# > Computing pc * log(pc) took 0.045501849 seconds; the result circuit has 27584 edges
# > Computing int(pc * log(pc)) took 0.029307078 seconds.
# > The entropy of pc is 36.706711083535474.
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing log(pc2) took 0.035986985 seconds; the result circuit has 45985 edges
# > Computing pc1 * log(pc2) took 0.083008872 seconds; the result circuit has 46197 edges
# > Computing int(pc1 * log(pc2)) took 0.016679654 seconds.
# > The cross entropy between pc1 and pc2 is 37.001537898136576.
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing 1/pc2 took 0.011332335 seconds; the result circuit has 12731 edges
# > Computing pc1/pc2 took 0.022206496 seconds; the result circuit has 12943 edges
# > Computing log(pc1/pc2) took 0.036178009 seconds; the result circuit has 46621 edges
# > Computing pc1 * log(pc1/pc2) took 0.120296171 seconds; the result circuit has 46621 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.015571911 seconds.
# > The KLD between pc1 and pc2 is 0.2948268146010812.
#
# 0.107& 0.002 & 0.173 & 0.037 & 0.245 & 0.036
# =========================================
# c20ng
#
# > Size of the input circuits: pc - 11386
# > Computing log(pc) took 0.029400985 seconds; the result circuit has 40188 edges
# > Computing pc * log(pc) took 0.056645058 seconds; the result circuit has 40188 edges
# > Computing int(pc * log(pc)) took 0.015149345 seconds.
# > The entropy of pc is 147.7955662472699.
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing log(pc2) took 0.07018811 seconds; the result circuit has 52120 edges
# > Computing pc1 * log(pc2) took 0.082901587 seconds; the result circuit has 52376 edges
# > Computing int(pc1 * log(pc2)) took 0.019905138 seconds.
# > The cross entropy between pc1 and pc2 is 148.0782504585418.
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing 1/pc2 took 0.012783743 seconds; the result circuit has 14630 edges
# > Computing pc1/pc2 took 0.023271954 seconds; the result circuit has 14886 edges
# > Computing log(pc1/pc2) took 0.039564132 seconds; the result circuit has 52888 edges
# > Computing pc1 * log(pc1/pc2) took 0.086505715 seconds; the result circuit has 52888 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.018640823 seconds.
# > The KLD between pc1 and pc2 is 0.28268421127200144.
#
# 0.117& 0.004 & 0.216 & 0.035 & 0.265 & 0.033
# =========================================
# cr52
#
# > Size of the input circuits: pc - 10912
# > Computing log(pc) took 0.029341262 seconds; the result circuit has 38466 edges
# > Computing pc * log(pc) took 0.056876954 seconds; the result circuit has 38466 edges
# > Computing int(pc * log(pc)) took 0.014164388 seconds.
# > The entropy of pc is 103.67129218526738.
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing log(pc2) took 0.039359164 seconds; the result circuit has 51094 edges
# > Computing pc1 * log(pc2) took 0.12360274 seconds; the result circuit has 51292 edges
# > Computing int(pc1 * log(pc2)) took 0.017718296 seconds.
# > The cross entropy between pc1 and pc2 is 103.86047923886721.
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing 1/pc2 took 0.013822758 seconds; the result circuit has 14348 edges
# > Computing pc1/pc2 took 0.02489276 seconds; the result circuit has 14546 edges
# > Computing log(pc1/pc2) took 0.039025366 seconds; the result circuit has 51688 edges
# > Computing pc1 * log(pc1/pc2) took 0.089132171 seconds; the result circuit has 51688 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.017981694 seconds.
# > The KLD between pc1 and pc2 is 0.18918705359984717.
#
# 0.115& 0.004 & 0.221 & 0.036 & 0.232 & 0.060
# =========================================
# cwebkb
#
# > Size of the input circuits: pc - 10598
# > Computing log(pc) took 0.027912709 seconds; the result circuit has 37564 edges
# > Computing pc * log(pc) took 0.054857757 seconds; the result circuit has 37564 edges
# > Computing int(pc * log(pc)) took 0.012655105 seconds.
# > The entropy of pc is 155.91078086898125.
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing log(pc2) took 0.036228527 seconds; the result circuit has 47859 edges
# > Computing pc1 * log(pc2) took 0.073522297 seconds; the result circuit has 48115 edges
# > Computing int(pc1 * log(pc2)) took 0.016908934 seconds.
# > The cross entropy between pc1 and pc2 is 156.25023067909387.
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing 1/pc2 took 0.037933599 seconds; the result circuit has 13397 edges
# > Computing pc1/pc2 took 0.021393048 seconds; the result circuit has 13653 edges
# > Computing log(pc1/pc2) took 0.040059877 seconds; the result circuit has 48627 edges
# > Computing pc1 * log(pc1/pc2) took 0.073931644 seconds; the result circuit has 48627 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016907251 seconds.
# > The KLD between pc1 and pc2 is 0.33944981011289377.
#
# 0.110& 0.004 & 0.166 & 0.033 & 0.235 & 0.031
# =========================================
# dna
#
# > Size of the input circuits: pc - 73828
# > Computing log(pc) took 0.491206826 seconds; the result circuit has 270535 edges
# > Computing pc * log(pc) took 3.656206975 seconds; the result circuit has 270535 edges
# > Computing int(pc * log(pc)) took 0.104396645 seconds.
# > The entropy of pc is 86.75201818365386.
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing log(pc2) took 3.754116566 seconds; the result circuit has 3141981 edges
# > Computing pc1 * log(pc2) took 43.426693864 seconds; the result circuit has 3142055 edges
# > Computing int(pc1 * log(pc2)) took 1.588796303 seconds.
# > The cross entropy between pc1 and pc2 is 93.30240984842088.
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing 1/pc2 took 1.364182773 seconds; the result circuit has 856955 edges
# > Computing pc1/pc2 took 9.200010215 seconds; the result circuit has 857029 edges
# > Computing log(pc1/pc2) took 4.48626382 seconds; the result circuit has 3142203 edges
# > Computing pc1 * log(pc1/pc2) took 42.24512966 seconds; the result circuit has 3142203 edges
# > Computing int(pc1 * log(pc1/pc2)) took 1.593264579 seconds.
# > The KLD between pc1 and pc2 is 6.550391664767006.
#
# 4.365& 0.027 & 52.997 & 230.756 & 64.664 & 220.377
# =========================================
# jester
#
# > Size of the input circuits: pc - 6475
# > Computing log(pc) took 0.017655546 seconds; the result circuit has 23636 edges
# > Computing pc * log(pc) took 0.101213855 seconds; the result circuit has 23636 edges
# > Computing int(pc * log(pc)) took 0.008247905 seconds.
# > The entropy of pc is 56.448165569922416.
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing log(pc2) took 0.097874384 seconds; the result circuit has 129579 edges
# > Computing pc1 * log(pc2) took 0.543017405 seconds; the result circuit has 129689 edges
# > Computing int(pc1 * log(pc2)) took 0.052790159 seconds.
# > The cross entropy between pc1 and pc2 is 57.51142426885051.
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing 1/pc2 took 0.031213355 seconds; the result circuit has 35369 edges
# > Computing pc1/pc2 took 0.140429841 seconds; the result circuit has 35479 edges
# > Computing log(pc1/pc2) took 0.10652003 seconds; the result circuit has 129909 edges
# > Computing pc1 * log(pc1/pc2) took 0.544830047 seconds; the result circuit has 129909 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.053745355 seconds.
# > The KLD between pc1 and pc2 is 1.0632586989280854.
#
# 0.136& 0.003 & 0.810 & 1.079 & 1.010 & 0.433
# =========================================
# kdd
#
# > Size of the input circuits: pc - 4963
# > Computing log(pc) took 0.013192044 seconds; the result circuit has 18127 edges
# > Computing pc * log(pc) took 0.124108609 seconds; the result circuit has 18127 edges
# > Computing int(pc * log(pc)) took 0.005835324 seconds.
# > The entropy of pc is 2.4499956450929483.
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing log(pc2) took 0.141992256 seconds; the result circuit has 184575 edges
# > Computing pc1 * log(pc2) took 1.781991154 seconds; the result circuit has 184615 edges
# > Computing int(pc1 * log(pc2)) took 0.075424386 seconds.
# > The cross entropy between pc1 and pc2 is 2.4822370246489984.
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing 1/pc2 took 0.046181377 seconds; the result circuit has 50377 edges
# > Computing pc1/pc2 took 0.447261646 seconds; the result circuit has 50417 edges
# > Computing log(pc1/pc2) took 0.154187615 seconds; the result circuit has 184695 edges
# > Computing pc1 * log(pc1/pc2) took 1.778820586 seconds; the result circuit has 184695 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.075437332 seconds.
# > The KLD between pc1 and pc2 is 0.03224137955604949.
#
# 0.149& 0.002 & 2.164 & 0.775 & 2.683 & 0.775
# =========================================
# kosarek
#
# > Size of the input circuits: pc - 5115
# > Computing log(pc) took 0.013133929 seconds; the result circuit has 18477 edges
# > Computing pc * log(pc) took 0.169103515 seconds; the result circuit has 18477 edges
# > Computing int(pc * log(pc)) took 0.005510212 seconds.
# > The entropy of pc is 11.485021503770145.
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing log(pc2) took 0.033151117 seconds; the result circuit has 47354 edges
# > Computing pc1 * log(pc2) took 0.326952004 seconds; the result circuit has 47472 edges
# > Computing int(pc1 * log(pc2)) took 0.015827247 seconds.
# > The cross entropy between pc1 and pc2 is 11.684428276120638.
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing 1/pc2 took 0.009693262 seconds; the result circuit has 12988 edges
# > Computing pc1/pc2 took 0.084539166 seconds; the result circuit has 13106 edges
# > Computing log(pc1/pc2) took 0.034662881 seconds; the result circuit has 47708 edges
# > Computing pc1 * log(pc1/pc2) took 0.329269918 seconds; the result circuit has 47708 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016401172 seconds.
# > The KLD between pc1 and pc2 is 0.19940677235049156.
#
# 0.194& 0.001 & 0.409 & 0.102 & 0.511 & 0.110
# =========================================
# msnbc
#
# > Size of the input circuits: pc - 2765
# > Computing log(pc) took 0.006674394 seconds; the result circuit has 10089 edges
# > Computing pc * log(pc) took 0.103814154 seconds; the result circuit has 10089 edges
# > Computing int(pc * log(pc)) took 0.00278256 seconds.
# > The entropy of pc is 6.282982749895639.
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing log(pc2) took 0.017035173 seconds; the result circuit has 24111 edges
# > Computing pc1 * log(pc2) took 0.255031119 seconds; the result circuit has 24131 edges
# > Computing int(pc1 * log(pc2)) took 0.007941234 seconds.
# > The cross entropy between pc1 and pc2 is 6.394007219999606.
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing 1/pc2 took 0.005218286 seconds; the result circuit has 6614 edges
# > Computing pc1/pc2 took 0.071104589 seconds; the result circuit has 6634 edges
# > Computing log(pc1/pc2) took 0.017309708 seconds; the result circuit has 24171 edges
# > Computing pc1 * log(pc1/pc2) took 0.275870078 seconds; the result circuit has 24171 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.008153223 seconds.
# > The KLD between pc1 and pc2 is 0.1110244701039657.
#
# 0.116& 0.001 & 0.297 & 0.195 & 0.396 & 0.181
# =========================================
# msweb
#
# > Size of the input circuits: pc - 4859
# > Computing log(pc) took 0.021382276 seconds; the result circuit has 17381 edges
# > Computing pc * log(pc) took 0.097538783 seconds; the result circuit has 17381 edges
# > Computing int(pc * log(pc)) took 0.005188582 seconds.
# > The entropy of pc is 10.155486310119123.
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing log(pc2) took 0.022990492 seconds; the result circuit has 32675 edges
# > Computing pc1 * log(pc2) took 0.155267423 seconds; the result circuit has 32825 edges
# > Computing int(pc1 * log(pc2)) took 0.02613637 seconds.
# > The cross entropy between pc1 and pc2 is 10.162931667964264.
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing 1/pc2 took 0.00717922 seconds; the result circuit has 9025 edges
# > Computing pc1/pc2 took 0.037220767 seconds; the result circuit has 9175 edges
# > Computing log(pc1/pc2) took 0.024736239 seconds; the result circuit has 33125 edges
# > Computing pc1 * log(pc1/pc2) took 0.160391987 seconds; the result circuit has 33125 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.010819284 seconds.
# > The KLD between pc1 and pc2 is 0.007445357845147155.
#
# 0.130& 0.001 & 0.227 & 0.046 & 0.268 & 0.054
# =========================================
# nltcs
#
# > Size of the input circuits: pc - 2779
# > Computing log(pc) took 0.006888585 seconds; the result circuit has 10129 edges
# > Computing pc * log(pc) took 0.13809452 seconds; the result circuit has 10129 edges
# > Computing int(pc * log(pc)) took 0.003071254 seconds.
# > The entropy of pc is 6.125420227013054.
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing log(pc2) took 0.019056035 seconds; the result circuit has 26155 edges
# > Computing pc1 * log(pc2) took 0.397279608 seconds; the result circuit has 26183 edges
# > Computing int(pc1 * log(pc2)) took 0.008811576 seconds.
# > The cross entropy between pc1 and pc2 is 6.2351072248353585.
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing 1/pc2 took 0.005806552 seconds; the result circuit has 7174 edges
# > Computing pc1/pc2 took 0.105572823 seconds; the result circuit has 7202 edges
# > Computing log(pc1/pc2) took 0.019685642 seconds; the result circuit has 26239 edges
# > Computing pc1 * log(pc1/pc2) took 0.402248492 seconds; the result circuit has 26239 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.008928355 seconds.
# > The KLD between pc1 and pc2 is 0.10968699782230651.
#
# 0.151& 0.001 & 0.443 & 0.216 & 0.563 & 0.224
# =========================================
# plants
#
# > Size of the input circuits: pc - 12909
# > Computing log(pc) took 0.050957643 seconds; the result circuit has 47275 edges
# > Computing pc * log(pc) took 0.634011827 seconds; the result circuit has 47275 edges
# > Computing int(pc * log(pc)) took 0.016810041 seconds.
# > The entropy of pc is 15.033179152400017.
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing log(pc2) took 0.233661087 seconds; the result circuit has 234661 edges
# > Computing pc1 * log(pc2) took 3.16639641 seconds; the result circuit has 234713 edges
# > Computing int(pc1 * log(pc2)) took 0.099544322 seconds.
# > The cross entropy between pc1 and pc2 is 16.311007100712775.
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing 1/pc2 took 0.058944571 seconds; the result circuit has 64018 edges
# > Computing pc1/pc2 took 0.6666195 seconds; the result circuit has 64070 edges
# > Computing log(pc1/pc2) took 0.19925723 seconds; the result circuit has 234817 edges
# > Computing pc1 * log(pc1/pc2) took 2.721034286 seconds; the result circuit has 234817 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.093744107 seconds.
# > The KLD between pc1 and pc2 is 1.2778279483127581.
#
# 0.718& 0.005 & 3.708 & 4.423 & 3.962 & 3.911
# =========================================
# pumsb_star
#
# > Size of the input circuits: pc - 4277
# > Computing log(pc) took 0.010987832 seconds; the result circuit has 15459 edges
# > Computing pc * log(pc) took 0.070743735 seconds; the result circuit has 15459 edges
# > Computing int(pc * log(pc)) took 0.004940719 seconds.
# > The entropy of pc is 30.448249698414923.
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing log(pc2) took 0.035413477 seconds; the result circuit has 45500 edges
# > Computing pc1 * log(pc2) took 0.228416054 seconds; the result circuit has 45634 edges
# > Computing int(pc1 * log(pc2)) took 0.016656334 seconds.
# > The cross entropy between pc1 and pc2 is 34.242918908879886.
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing 1/pc2 took 0.01083805 seconds; the result circuit has 12461 edges
# > Computing pc1/pc2 took 0.064758461 seconds; the result circuit has 12595 edges
# > Computing log(pc1/pc2) took 0.037068826 seconds; the result circuit has 45902 edges
# > Computing pc1 * log(pc1/pc2) took 0.231318533 seconds; the result circuit has 45902 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.016208875 seconds.
# > The KLD between pc1 and pc2 is 3.794669210464959.
#
# 0.092& 0.001 & 0.315 & 0.120 & 0.396 & 0.120
# =========================================
# tmovie
#
# > Size of the input circuits: pc - 8309
# > Computing log(pc) took 0.023138678 seconds; the result circuit has 29803 edges
# > Computing pc * log(pc) took 0.206209605 seconds; the result circuit has 29803 edges
# > Computing int(pc * log(pc)) took 0.010025605 seconds.
# > The entropy of pc is 65.39573682801425.
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing log(pc2) took 0.033231085 seconds; the result circuit has 42374 edges
# > Computing pc1 * log(pc2) took 0.259221868 seconds; the result circuit has 42568 edges
# > Computing int(pc1 * log(pc2)) took 0.015040531 seconds.
# > The cross entropy between pc1 and pc2 is 65.54253059963418.
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing 1/pc2 took 0.009973321 seconds; the result circuit has 11732 edges
# > Computing pc1/pc2 took 0.065712001 seconds; the result circuit has 11926 edges
# > Computing log(pc1/pc2) took 0.034451167 seconds; the result circuit has 42956 edges
# > Computing pc1 * log(pc1/pc2) took 0.259317803 seconds; the result circuit has 42956 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.01500439 seconds.
# > The KLD between pc1 and pc2 is 0.1467937716198886.
#
# 0.249& 0.003 & 0.338 & 0.066 & 0.419 & 0.065
# =========================================
# tretail
#
# > Size of the input circuits: pc - 4790
# > Computing log(pc) took 0.014168965 seconds; the result circuit has 17383 edges
# > Computing pc * log(pc) took 0.076604356 seconds; the result circuit has 17383 edges
# > Computing int(pc * log(pc)) took 0.005699197 seconds.
# > The entropy of pc is 10.813896439395194.
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing log(pc2) took 0.043654067 seconds; the result circuit has 54554 edges
# > Computing pc1 * log(pc2) took 0.601992141 seconds; the result circuit has 54622 edges
# > Computing int(pc1 * log(pc2)) took 0.018111741 seconds.
# > The cross entropy between pc1 and pc2 is 10.855694725567409.
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing 1/pc2 took 0.011715466 seconds; the result circuit has 14926 edges
# > Computing pc1/pc2 took 0.06900222 seconds; the result circuit has 14994 edges
# > Computing log(pc1/pc2) took 0.060019721 seconds; the result circuit has 54758 edges
# > Computing pc1 * log(pc1/pc2) took 0.289398876 seconds; the result circuit has 54758 edges
# > Computing int(pc1 * log(pc1/pc2)) took 0.018513135 seconds.
# > The KLD between pc1 and pc2 is 0.04179828617221294.
#
# 0.102& 0.001 & 0.701 & 0.147 & 0.510 & 0.152

# %%
for dataset_name in twenty_dataset_names[1:end-1]
    pc1 = load_prob_circuit("pcs/$(dataset_name)_200.psdd");
    pc2 = load_prob_circuit("pcs/$(dataset_name)_500.psdd");
    
    println("=========================================")
    println(dataset_name)
    println("")
    t1 = @elapsed reiny_alpha_div(pc1, pc2; alpha = 1.5)
    t2 = @elapsed renyi_entropy(pc1; alpha = 1.5)
    t3 = @elapsed cs_div(pc1, pc2)
    
    @printf("& %.3f & -\n", t1)
    @printf("& %.3f & - & %.3f & -\n\n", t2, t3)
end
# Out:
# =========================================
# accidents
#
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing pc1^alpha took 0.007907935 seconds; the result circuit has 3193 edges
# > Computing pc2^(1-alpha) took 0.012534101 seconds; the result circuit has 8183 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.037019082 seconds; the result circuit has 8299 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005026501 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -6.555987547340751.
# > Size of the input circuit: pc - 3193
# > Computing pc^alpha took 0.005521597 seconds; the result circuit has 3193 edges
# > Computing int(pc^alpha) took 0.001815432 seconds.
# > Size of the input circuits: pc1 - 3193, pc2 - 8183
# > Computing pc1*pc2 took 0.085990308 seconds; the result circuit has 8299 edges
# > Computing pc1^2 took 0.005486886 seconds; the result circuit has 3193 edges
# > Computing pc2^2 took 0.01364998 seconds; the result circuit has 8183 edges
# > Computing cs div took 0.011379333 seconds.
# & 0.074 & -
# & 0.009 & - & 0.124 & -
#
# =========================================
# ad
#
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing pc1^alpha took 0.047791447 seconds; the result circuit has 17744 edges
# > Computing pc2^(1-alpha) took 0.068102765 seconds; the result circuit has 21676 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.032732039 seconds; the result circuit has 21920 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.008424178 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.19909141036434766.
# > Size of the input circuit: pc - 17744
# > Computing pc^alpha took 0.017373011 seconds; the result circuit has 17744 edges
# > Computing int(pc^alpha) took 0.006843515 seconds.
# > Size of the input circuits: pc1 - 17744, pc2 - 21676
# > Computing pc1*pc2 took 0.03402544 seconds; the result circuit has 21920 edges
# > Computing pc1^2 took 0.03413086 seconds; the result circuit has 17744 edges
# > Computing pc2^2 took 0.041815575 seconds; the result circuit has 21676 edges
# > Computing cs div took 0.07343033 seconds.
# & 0.199 & -
# & 0.031 & - & 0.207 & -
#
# =========================================
# baudio
#
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing pc1^alpha took 0.019134804 seconds; the result circuit has 10278 edges
# > Computing pc2^(1-alpha) took 0.070808221 seconds; the result circuit has 45864 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.642161057 seconds; the result circuit has 45950 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.029836993 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -1.1474421894496463.
# > Size of the input circuit: pc - 10278
# > Computing pc^alpha took 0.018041626 seconds; the result circuit has 10278 edges
# > Computing int(pc^alpha) took 0.005939933 seconds.
# > Size of the input circuits: pc1 - 10278, pc2 - 45864
# > Computing pc1*pc2 took 0.564460012 seconds; the result circuit has 45950 edges
# > Computing pc1^2 took 0.017260096 seconds; the result circuit has 10278 edges
# > Computing pc2^2 took 0.084559424 seconds; the result circuit has 45864 edges
# > Computing cs div took 0.061228786 seconds.
# & 0.845 & -
# & 0.029 & - & 0.771 & -
#
# =========================================
# bbc
#
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing pc1^alpha took 0.015517416 seconds; the result circuit has 13884 edges
# > Computing pc2^(1-alpha) took 0.021823746 seconds; the result circuit has 17016 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.052013293 seconds; the result circuit has 17282 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.011020844 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.5514099793516106.
# > Size of the input circuit: pc - 13884
# > Computing pc^alpha took 0.024091862 seconds; the result circuit has 13884 edges
# > Computing int(pc^alpha) took 0.007554215 seconds.
# > Size of the input circuits: pc1 - 13884, pc2 - 17016
# > Computing pc1*pc2 took 0.051681444 seconds; the result circuit has 17282 edges
# > Computing pc1^2 took 0.02487583 seconds; the result circuit has 13884 edges
# > Computing pc2^2 took 0.033643706 seconds; the result circuit has 17016 edges
# > Computing cs div took 0.028252846 seconds.
# & 0.131 & -
# & 0.038 & - & 0.189 & -
#
# =========================================
# bnetflix
#
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing pc1^alpha took 0.008557458 seconds; the result circuit has 5068 edges
# > Computing pc2^(1-alpha) took 0.018372041 seconds; the result circuit has 14636 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.083570461 seconds; the result circuit has 14706 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.011369168 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.8237090208137337.
# > Size of the input circuit: pc - 5068
# > Computing pc^alpha took 0.010647521 seconds; the result circuit has 5068 edges
# > Computing int(pc^alpha) took 0.003612424 seconds.
# > Size of the input circuits: pc1 - 5068, pc2 - 14636
# > Computing pc1*pc2 took 0.0976359 seconds; the result circuit has 14706 edges
# > Computing pc1^2 took 0.010676364 seconds; the result circuit has 5068 edges
# > Computing pc2^2 took 0.029810902 seconds; the result circuit has 14636 edges
# > Computing cs div took 0.04748241 seconds.
# & 0.143 & -
# & 0.017 & - & 0.201 & -
#
# =========================================
# book
#
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing pc1^alpha took 0.008358502 seconds; the result circuit has 7718 edges
# > Computing pc2^(1-alpha) took 0.014425079 seconds; the result circuit has 12731 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.029687201 seconds; the result circuit has 12943 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005815872 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.42067644194405474.
# > Size of the input circuit: pc - 7718
# > Computing pc^alpha took 0.011483785 seconds; the result circuit has 7718 edges
# > Computing int(pc^alpha) took 0.004676231 seconds.
# > Size of the input circuits: pc1 - 7718, pc2 - 12731
# > Computing pc1*pc2 took 0.043521999 seconds; the result circuit has 12943 edges
# > Computing pc1^2 took 0.013845692 seconds; the result circuit has 7718 edges
# > Computing pc2^2 took 0.025106622 seconds; the result circuit has 12731 edges
# > Computing cs div took 0.019918191 seconds.
# & 0.073 & -
# & 0.020 & - & 0.115 & -
#
# =========================================
# c20ng
#
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing pc1^alpha took 0.017686193 seconds; the result circuit has 11386 edges
# > Computing pc2^(1-alpha) took 0.025838773 seconds; the result circuit has 14630 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.04599173 seconds; the result circuit has 14886 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.009336689 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.4650706460435336.
# > Size of the input circuit: pc - 11386
# > Computing pc^alpha took 0.020149019 seconds; the result circuit has 11386 edges
# > Computing int(pc^alpha) took 0.006027749 seconds.
# > Size of the input circuits: pc1 - 11386, pc2 - 14630
# > Computing pc1*pc2 took 0.044177075 seconds; the result circuit has 14886 edges
# > Computing pc1^2 took 0.013917349 seconds; the result circuit has 11386 edges
# > Computing pc2^2 took 0.014367826 seconds; the result circuit has 14630 edges
# > Computing cs div took 0.015293863 seconds.
# & 0.127 & -
# & 0.032 & - & 0.101 & -
#
# =========================================
# cr52
#
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing pc1^alpha took 0.018317319 seconds; the result circuit has 10912 edges
# > Computing pc2^(1-alpha) took 0.024943808 seconds; the result circuit has 14348 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.047993679 seconds; the result circuit has 14546 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.00892955 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.3244837684761142.
# > Size of the input circuit: pc - 10912
# > Computing pc^alpha took 0.019455378 seconds; the result circuit has 10912 edges
# > Computing int(pc^alpha) took 0.00591509 seconds.
# > Size of the input circuits: pc1 - 10912, pc2 - 14348
# > Computing pc1*pc2 took 0.047194356 seconds; the result circuit has 14546 edges
# > Computing pc1^2 took 0.019879476 seconds; the result circuit has 10912 edges
# > Computing pc2^2 took 0.036581666 seconds; the result circuit has 14348 edges
# > Computing cs div took 0.02382227 seconds.
# & 0.125 & -
# & 0.031 & - & 0.143 & -
#
# =========================================
# cwebkb
#
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing pc1^alpha took 0.017674892 seconds; the result circuit has 10598 edges
# > Computing pc2^(1-alpha) took 0.019031089 seconds; the result circuit has 13397 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.02810324 seconds; the result circuit has 13653 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.00618988 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.48145521926605633.
# > Size of the input circuit: pc - 10598
# > Computing pc^alpha took 0.012551507 seconds; the result circuit has 10598 edges
# > Computing int(pc^alpha) took 0.006037552 seconds.
# > Size of the input circuits: pc1 - 10598, pc2 - 13397
# > Computing pc1*pc2 took 0.040103649 seconds; the result circuit has 13653 edges
# > Computing pc1^2 took 0.018846361 seconds; the result circuit has 10598 edges
# > Computing pc2^2 took 0.013131724 seconds; the result circuit has 13397 edges
# > Computing cs div took 0.013234701 seconds.
# & 0.090 & -
# & 0.023 & - & 0.098 & -
#
# =========================================
# dna
#
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing pc1^alpha took 0.128730661 seconds; the result circuit has 73828 edges
# > Computing pc2^(1-alpha) took 1.68325317 seconds; the result circuit has 856955 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 18.229987897 seconds; the result circuit has 857029 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.927158558 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -13.621780838550412.
# > Size of the input circuit: pc - 73828
# > Computing pc^alpha took 0.156495166 seconds; the result circuit has 73828 edges
# > Computing int(pc^alpha) took 0.060198745 seconds.
# > Size of the input circuits: pc1 - 73828, pc2 - 856955
# > Computing pc1*pc2 took 18.141567565 seconds; the result circuit has 857029 edges
# > Computing pc1^2 took 0.23381595 seconds; the result circuit has 73828 edges
# > Computing pc2^2 took 1.913820735 seconds; the result circuit has 856955 edges
# > Computing cs div took 1.577883813 seconds.
# & 22.749 & -
# & 0.255 & - & 22.901 & -
#
# =========================================
# jester
#
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing pc1^alpha took 0.012309395 seconds; the result circuit has 6475 edges
# > Computing pc2^(1-alpha) took 0.079030067 seconds; the result circuit has 35369 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.396190341 seconds; the result circuit has 35479 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.031668146 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -1.6853136774624742.
# > Size of the input circuit: pc - 6475
# > Computing pc^alpha took 0.014799683 seconds; the result circuit has 6475 edges
# > Computing int(pc^alpha) took 0.005079294 seconds.
# > Size of the input circuits: pc1 - 6475, pc2 - 35369
# > Computing pc1*pc2 took 0.320591756 seconds; the result circuit has 35479 edges
# > Computing pc1^2 took 0.007184772 seconds; the result circuit has 6475 edges
# > Computing pc2^2 took 0.062628082 seconds; the result circuit has 35369 edges
# > Computing cs div took 0.05538273 seconds.
# & 0.582 & -
# & 0.024 & - & 0.476 & -
#
# =========================================
# kdd
#
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing pc1^alpha took 0.021644658 seconds; the result circuit has 4963 edges
# > Computing pc2^(1-alpha) took 0.103821317 seconds; the result circuit has 50377 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.879667022 seconds; the result circuit has 50417 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.036389228 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.07304605092566026.
# > Size of the input circuit: pc - 4963
# > Computing pc^alpha took 0.009501563 seconds; the result circuit has 4963 edges
# > Computing int(pc^alpha) took 0.003457155 seconds.
# > Size of the input circuits: pc1 - 4963, pc2 - 50377
# > Computing pc1*pc2 took 0.87939506 seconds; the result circuit has 50417 edges
# > Computing pc1^2 took 0.011052646 seconds; the result circuit has 4963 edges
# > Computing pc2^2 took 0.107131033 seconds; the result circuit has 50377 edges
# > Computing cs div took 0.0867347 seconds.
# & 1.118 & -
# & 0.016 & - & 1.136 & -
#
# =========================================
# kosarek
#
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing pc1^alpha took 0.009341367 seconds; the result circuit has 5115 edges
# > Computing pc2^(1-alpha) took 0.021754561 seconds; the result circuit has 12988 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.154879448 seconds; the result circuit has 13106 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.0059787 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.3414242734454531.
# > Size of the input circuit: pc - 5115
# > Computing pc^alpha took 0.006336278 seconds; the result circuit has 5115 edges
# > Computing int(pc^alpha) took 0.002439621 seconds.
# > Size of the input circuits: pc1 - 5115, pc2 - 12988
# > Computing pc1*pc2 took 0.680021221 seconds; the result circuit has 13106 edges
# > Computing pc1^2 took 0.00602346 seconds; the result circuit has 5115 edges
# > Computing pc2^2 took 0.019285733 seconds; the result circuit has 12988 edges
# > Computing cs div took 0.019230203 seconds.
# & 0.208 & -
# & 0.011 & - & 0.735 & -
#
# =========================================
# msnbc
#
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing pc1^alpha took 0.004325776 seconds; the result circuit has 2765 edges
# > Computing pc2^(1-alpha) took 0.010789557 seconds; the result circuit has 6614 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.144477027 seconds; the result circuit has 6634 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004161561 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.18313379427044257.
# > Size of the input circuit: pc - 2765
# > Computing pc^alpha took 0.004401095 seconds; the result circuit has 2765 edges
# > Computing int(pc^alpha) took 0.001438045 seconds.
# > Size of the input circuits: pc1 - 2765, pc2 - 6614
# > Computing pc1*pc2 took 0.194981359 seconds; the result circuit has 6634 edges
# > Computing pc1^2 took 0.004387003 seconds; the result circuit has 2765 edges
# > Computing pc2^2 took 0.010864732 seconds; the result circuit has 6614 edges
# > Computing cs div took 0.009874886 seconds.
# & 0.174 & -
# & 0.018 & - & 0.227 & -
#
# =========================================
# msweb
#
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing pc1^alpha took 0.008613983 seconds; the result circuit has 4859 edges
# > Computing pc2^(1-alpha) took 0.010505539 seconds; the result circuit has 9025 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.054612682 seconds; the result circuit has 9175 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.005747337 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.01038327650773606.
# > Size of the input circuit: pc - 4859
# > Computing pc^alpha took 0.008602357 seconds; the result circuit has 4859 edges
# > Computing int(pc^alpha) took 0.002978464 seconds.
# > Size of the input circuits: pc1 - 4859, pc2 - 9025
# > Computing pc1*pc2 took 0.084887487 seconds; the result circuit has 9175 edges
# > Computing pc1^2 took 0.009144902 seconds; the result circuit has 4859 edges
# > Computing pc2^2 took 0.015683483 seconds; the result circuit has 9025 edges
# > Computing cs div took 0.015031114 seconds.
# & 0.094 & -
# & 0.015 & - & 0.135 & -
#
# =========================================
# nltcs
#
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing pc1^alpha took 0.004632062 seconds; the result circuit has 2779 edges
# > Computing pc2^(1-alpha) took 0.008190913 seconds; the result circuit has 7174 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.301269734 seconds; the result circuit has 7202 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004077177 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.2136957947761329.
# > Size of the input circuit: pc - 2779
# > Computing pc^alpha took 0.010771526 seconds; the result circuit has 2779 edges
# > Computing int(pc^alpha) took 0.001458573 seconds.
# > Size of the input circuits: pc1 - 2779, pc2 - 7174
# > Computing pc1*pc2 took 0.264211048 seconds; the result circuit has 7202 edges
# > Computing pc1^2 took 0.004554679 seconds; the result circuit has 2779 edges
# > Computing pc2^2 took 0.01484655 seconds; the result circuit has 7174 edges
# > Computing cs div took 0.009300891 seconds.
# & 0.339 & -
# & 0.013 & - & 0.300 & -
#
# =========================================
# plants
#
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing pc1^alpha took 0.038952357 seconds; the result circuit has 12909 edges
# > Computing pc2^(1-alpha) took 0.180755746 seconds; the result circuit has 64018 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 1.454366649 seconds; the result circuit has 64070 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.046293475 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -3.8712657353901805.
# > Size of the input circuit: pc - 12909
# > Computing pc^alpha took 0.07478535 seconds; the result circuit has 12909 edges
# > Computing int(pc^alpha) took 0.007590373 seconds.
# > Size of the input circuits: pc1 - 12909, pc2 - 64018
# > Computing pc1*pc2 took 1.335761411 seconds; the result circuit has 64070 edges
# > Computing pc1^2 took 0.01442063 seconds; the result circuit has 12909 edges
# > Computing pc2^2 took 0.073337793 seconds; the result circuit has 64018 edges
# > Computing cs div took 0.101020912 seconds.
# & 1.813 & -
# & 0.088 & - & 1.572 & -
#
# =========================================
# pumsb_star
#
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing pc1^alpha took 0.003479714 seconds; the result circuit has 4277 edges
# > Computing pc2^(1-alpha) took 0.010140574 seconds; the result circuit has 12461 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.10438439 seconds; the result circuit has 12595 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.007605147 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -19.39999031349208.
# > Size of the input circuit: pc - 4277
# > Computing pc^alpha took 0.007319229 seconds; the result circuit has 4277 edges
# > Computing int(pc^alpha) took 0.002313062 seconds.
# > Size of the input circuits: pc1 - 4277, pc2 - 12461
# > Computing pc1*pc2 took 0.132402274 seconds; the result circuit has 12595 edges
# > Computing pc1^2 took 0.032559692 seconds; the result circuit has 4277 edges
# > Computing pc2^2 took 0.021154332 seconds; the result circuit has 12461 edges
# > Computing cs div took 0.017298828 seconds.
# & 0.140 & -
# & 0.012 & - & 0.214 & -
#
# =========================================
# tmovie
#
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing pc1^alpha took 0.009268092 seconds; the result circuit has 8309 edges
# > Computing pc2^(1-alpha) took 0.012444688 seconds; the result circuit has 11732 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.084923667 seconds; the result circuit has 11926 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.004635846 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.25634862557081556.
# > Size of the input circuit: pc - 8309
# > Computing pc^alpha took 0.009130272 seconds; the result circuit has 8309 edges
# > Computing int(pc^alpha) took 0.00300164 seconds.
# > Size of the input circuits: pc1 - 8309, pc2 - 11732
# > Computing pc1*pc2 took 0.130023612 seconds; the result circuit has 11926 edges
# > Computing pc1^2 took 0.014052356 seconds; the result circuit has 8309 edges
# > Computing pc2^2 took 0.019510411 seconds; the result circuit has 11732 edges
# > Computing cs div took 0.018672646 seconds.
# & 0.126 & -
# & 0.015 & - & 0.194 & -
#
# =========================================
# tretail
#
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing pc1^alpha took 0.008253767 seconds; the result circuit has 4790 edges
# > Computing pc2^(1-alpha) took 0.02423804 seconds; the result circuit has 14926 edges
# > Computing pc1^alpha * pc2^(1-alpha) took 0.249060332 seconds; the result circuit has 14994 edges
# > Computing int(pc1^alpha * pc2^(1-alpha)) took 0.008417532 seconds.
# > The Reiny's Alpha Divergence between pc1 and pc2 is -0.06841491024348624.
# > Size of the input circuit: pc - 4790
# > Computing pc^alpha took 0.008204872 seconds; the result circuit has 4790 edges
# > Computing int(pc^alpha) took 0.00263176 seconds.
# > Size of the input circuits: pc1 - 4790, pc2 - 14926
# > Computing pc1*pc2 took 0.138074021 seconds; the result circuit has 14994 edges
# > Computing pc1^2 took 0.008344429 seconds; the result circuit has 4790 edges
# > Computing pc2^2 took 0.022823434 seconds; the result circuit has 14926 edges
# > Computing cs div took 0.015458048 seconds.
# & 0.308 & -
# & 0.013 & - & 0.197 & -
